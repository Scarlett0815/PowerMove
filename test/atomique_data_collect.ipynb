# %%
import yaml

data = []

res_dict = []
file_path = "data/atomique_maintable/qsim/fpqac/res.yml"
with open(file_path, "r") as file:
    res_list = yaml.load(file, Loader=yaml.FullLoader)
    res_dict.extend(res_list)


for res_object in res_dict:
    # print("benchmark", res_object['benchmark'])
    # nqubit = int(res_object['benchmark'].split('/')[3].split('_')[0][1:])
    # move_nstage = res_object['circ_stats']['depth']
    # n_2q_gates = res_object['circ_stats']['n_2q_gate']
    # fidelity = res_object['fidelity']['total_fidelity'] / (0.9975 ** n_2q_gates) * (0.995 ** n_2q_gates) * (0.9975 ** (nqubit * move_nstage - 2 * n_2q_gates))
    # print(fidelity)
    for key in res_object.keys():
        print(key, res_object[key])
# Out:
# benchmark benchmarks/qsim/rand/q20_10_p0.5/i0.txt
# circ_stats {'avg_move_distance': 0.0032307127722064313, 'avg_move_speed': 0.06606774585289225, 'compilation_time': 1.8933162689208984, 'depth': 163, 'each_move_distance_mean': 1.3213549171389098, 'each_move_distance_std': 2.6103327630539885, 'max_ancilla': 4, 'n_1q_gate': 92, 'n_2q_gate': 182, 'n_2q_layer': 163, 'n_cooling': 0, 'n_move': 163, 'n_transfer': 0}
# fidelity {'1q_decoherence': 0.9999260444015164, '1q_gate': 0.9926667262173304, '1q_total': 0.9925933129554984, '2q_decoherence': 0.9998967719950361, '2q_gate': 0.6340866260707209, '2q_total': 0.6340211705733373, 'additional_2Q_by_cooling': 1.0, 'additional_2Q_error_by_heating': 0.7821602451361841, 'move_total': 0.7209424400305137, 'movement_atomloss': 0.999999663969341, 'movement_decoherence': 0.9217327098538904, 'total_fidelity': 0.4537072266483449, 'transfer': 1.0, 'transfer_decoherence': 1.0, 'transfer_total': 1.0}
# ...
